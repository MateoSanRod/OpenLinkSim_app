# %%
import pandas as pd

# %%
file_path = r"C:\Users\teoto\Downloads\PMKS+ Desktop\New folder\Kinematic Data from PMKSD  22_35_18_23_11_2024.txt".replace('\\', '/')
df = pd.read_csv(file_path, delimiter='\t', encoding='utf-16')
df

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['mathtext.fontset'] = 'custom'
plt.rcParams['font.family'], plt.rcParams['mathtext.rm'], plt.rcParams['mathtext.it'], \
    plt.rcParams['mathtext.bf'], plt.rcParams['mathtext.sf'] = 5 * ['Times New Roman']

# Set up the figure and axis
fig, ax1 = plt.subplots(figsize=(10, 4))
plt.rcParams['hatch.linewidth'] = 3

# Plot for df['column1'] on the left y-axis
ax1.plot(df['TimeSteps'], df['x 3,4']/100,
         color='tab:blue',
         linestyle='--',
         label='Slider displacement', linewidth=1)
ax1.set_ylabel(r'Displacement [$m$]', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis for velocity
ax2 = ax1.twinx()
ax2.plot(df['TimeSteps'], df['Vx 3,4']/100,
         color='tab:red',
         linestyle='--',
         label='Slider velocity', linewidth=1)
ax2.set_ylabel('Velocity [$m/s$]', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

# Create a third y-axis for acceleration
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))  # Offset the third axis
ax3.plot(df['TimeSteps'], df['Ax 3,4']/100,
         color='tab:green',
         linestyle='--',
         label='Slider acceleration', linewidth=1)
ax3.set_ylabel('Acceleration [$m/s^2$]', color='tab:green')
ax3.tick_params(axis='y', labelcolor='tab:green')

ax1.set_xticks(np.arange(0, 2 + .1, 0.5))
ax1.set_xticks(np.arange(0, 2 + .1, 0.25), minor=True)
ax1.set_xlim(0, 2)

# Additional settings for the x-axis
ax1.set_xlabel('Time (s)')

# Show the legend for all axes
fig.legend(loc='upper center', bbox_to_anchor=(0.5, 1), ncol=7)

# Save or display the plot
plt.savefig('multi_column_plot.png', dpi=300)
# Adjust layout to prevent clipping when saving
fig.tight_layout(rect=[0, 0, 1, 0.95])

# Save or display the plot
plt.savefig('multi_column_plot.png', dpi=300)

# %%
df.columns

# %%
df = pd.read_csv("C:/Users/teoto/OneDrive/Escritorio/RotaryMotor2.csv",
    skiprows=1,       header=0,         # treat the next line as the header
    index_col=False,  # do not interpret any column as the index
    quotechar='"')
df
# Out:
#      Time (sec)  Motor Torque12 (newton-meter)
# 0      0.000000                      -0.043064
# 1      0.016667                      -0.026825
# 2      0.033333                      -0.018451
# 3      0.050000                       0.020921
# 4      0.066667                       0.050242
# ..          ...                            ...
# 116    1.933333                      -0.115941
# 117    1.950000                      -0.099963
# 118    1.966667                      -0.082472
# 119    1.983333                      -0.063486
# 120    2.000000                      -0.043064
#
# [121 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Plot13'], dtype='object')

# %%
t = df["Time (sec)"]
torque = df.iloc[:, 1]  # the second column, “Motor Torque12 (newton‑meter)”
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(t, torque, linestyle='--', lw=1, color="tab:blue", label=r"$F_x(\Phi_1)$")

ax.set_title(r"Reaction Force of node 3 vs independent variable $\Phi_1$, gravity $g = 0 m/s^2$")
ax.set_xlabel("independent variable $\Phi_1$ (rad)")
ax.set_ylabel(r"Forces (N)")
ax.legend(loc="lower left")
ax.grid(True, linestyle='-.', linewidth=0.5, alpha=0.25)
# ax.set_xlim(0, simulation.delta_time * len(x))
fig.tight_layout()
fig.savefig("test.png", dpi=700)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\PycharmProjects\CDIM_app\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time (sec)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 t = df["Time (sec)"]
# ...
